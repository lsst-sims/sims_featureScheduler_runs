# %%
import numpy as np
import healpy as hp
import matplotlib.pylab as plt
# %matplotlib inline
from comCam_runs import greedy_comcam, run_sched, blob_comcam

# %%
nside = 256
survey_length = 2.  # Days
survey_lol = blob_comcam(nexp=1, nside=nside)

# %%
observatory, scheduler, observations = run_sched(survey_lol, nside=nside, 
                                                 fileroot='comcam_blob', n_visit_limit=None)
# Out:
# progress = 0.10%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-31f86ca531e6> in <module>
#       1 observatory, scheduler, observations = run_sched(survey_lol, nside=nside,
# ----> 2                                                  fileroot='comcam_blob', n_visit_limit=None)
#
# ~/git_repos/sims_featureScheduler_runs/comCam/comCam_runs.py in run_sched(surveys, survey_length, nside, fileroot, n_visit_limit)
#     104                                                          survey_length=survey_length,
#     105                                                          filename=fileroot + '%iyrs.db' % years,
# --> 106                                                          delete_past=True, n_visit_limit=n_visit_limit)
#     107     return observatory, scheduler, observations
#     108
#
# ~/git_repos/sims_featureScheduler/python/lsst/sims/featureScheduler/sim_runner.py in sim_runner(observatory, scheduler, filter_scheduler, mjd_start, survey_length, filename, delete_past, n_visit_limit, step_none)
#      47         if not scheduler._check_queue_mjd_only(observatory.mjd):
#      48             scheduler.update_conditions(observatory.return_conditions())
# ---> 49         desired_obs = scheduler.request_observation()
#      50         if desired_obs is None:
#      51             # No observation. Just step into the future and try again.
#
# ~/git_repos/sims_featureScheduler/python/lsst/sims/featureScheduler/schedulers/core_scheduler.py in request_observation(self)
#     136         """
#     137         if len(self.queue) == 0:
# --> 138             self._fill_queue()
#     139
#     140         if len(self.queue) == 0:
#
# ~/git_repos/sims_featureScheduler/python/lsst/sims/featureScheduler/schedulers/core_scheduler.py in _fill_queue(self)
#     189
#     190             # Survey return list of observations
# --> 191             result = self.survey_lists[self.survey_index[0]][self.survey_index[1]].generate_observations(self.conditions)
#     192             self.queue = result
#     193             self.queue_is_sequence = self.survey_lists[self.survey_index[0]][self.survey_index[1]].sequence
#
# ~/git_repos/sims_featureScheduler/python/lsst/sims/featureScheduler/surveys/base_survey.py in generate_observations(self, conditions)
#     115
#     116     def generate_observations(self, conditions):
# --> 117         observations = self.generate_observations_rough(conditions)
#     118         for detailer in self.detailers:
#     119             observations = detailer(observations, conditions)
#
# ~/git_repos/sims_featureScheduler/python/lsst/sims/featureScheduler/surveys/surveys.py in generate_observations_rough(self, conditions)
#     281         towns = np.vstack((pointing_x, pointing_y)).T
#     282         # Leaving optimize=False for speed. The optimization step doesn't usually improve much.
# --> 283         better_order = tsp_convex(towns, optimize=False)
#     284         # XXX-TODO: Could try to roll better_order to start at the nearest/fastest slew from current position.
#     285         observations = []
#
# ~/git_repos/sims_featureScheduler/python/lsst/sims/featureScheduler/utils/tsp.py in tsp_convex(towns, optimize, niter)
#     177     hull_verts = generate_hulls(towns)
#     178     dist_matrix = generate_dist_matrix(towns)
# --> 179     route = merge_hulls(hull_verts, dist_matrix)
#     180     if optimize:
#     181         distance = route_length(route, dist_matrix)
#
# ~/git_repos/sims_featureScheduler/python/lsst/sims/featureScheduler/utils/tsp.py in merge_hulls(indices_lists, dist_matrix)
#     105                 collapsed_indices.rotate(1)
#     106                 possible_results.append(collapsed_indices + dindex)
# --> 107                 possible_lengths.append(route_length(possible_results[-1], dist_matrix))
#     108             best = np.min(np.where(possible_lengths == np.min(possible_lengths)))
#     109             collapsed_indices = possible_results[best]
#
# ~/git_repos/sims_featureScheduler/python/lsst/sims/featureScheduler/utils/tsp.py in route_length(town_indx, dist_matrix)
#      41     # This closes the path and return to the start
#      42     town_i = town_indx
# ---> 43     town_j = np.roll(town_indx, -1)
#      44     distances = dist_matrix[town_i, town_j]
#      45     return np.sum(distances)
#
# ~/lsst/python/miniconda3-4.5.4/envs/lsst-scipipe-fcd27eb/lib/python3.6/site-packages/numpy/core/numeric.py in roll(a, shift, axis)
#    1366
#    1367     """
# -> 1368     a = asanyarray(a)
#    1369     if axis is None:
#    1370         return roll(a.ravel(), shift, 0).reshape(a.shape)
#
# ~/lsst/python/miniconda3-4.5.4/envs/lsst-scipipe-fcd27eb/lib/python3.6/site-packages/numpy/core/numeric.py in asanyarray(a, dtype, order)
#     542
#     543     """
# --> 544     return array(a, dtype, copy=False, order=order, subok=True)
#     545
#     546
#
# KeyboardInterrupt:

# %%
hp.mollview(scheduler.survey_lists[0][2].basis_functions[1].survey_features['N_obs'].feature, max=10)

# %%
conditions = observatory.return_conditions()

# %%
reward = scheduler.survey_lists[0][2].calc_reward_function(conditions)

# %%
hp.mollview(reward)
# Out:
# /Users/yoachim/lsst/stack/miniconda3-4.5.4-fcd27eb/DarwinX86/healpy/1.10.3.lsst2+1/lib/python/healpy-1.10.3-py3.6-macosx-10.7-x86_64.egg/healpy/pixelfunc.py:304: RuntimeWarning: invalid value encountered in less_equal
#   return np.absolute(m - badval) <= atol + rtol * np.absolute(badval)
# /Users/yoachim/lsst/stack/miniconda3-4.5.4-fcd27eb/DarwinX86/healpy/1.10.3.lsst2+1/lib/python/healpy-1.10.3-py3.6-macosx-10.7-x86_64.egg/healpy/projaxes.py:1049: RuntimeWarning: invalid value encountered in less
#   result.data[result.data<0]=0.0
# /Users/yoachim/lsst/stack/miniconda3-4.5.4-fcd27eb/DarwinX86/healpy/1.10.3.lsst2+1/lib/python/healpy-1.10.3-py3.6-macosx-10.7-x86_64.egg/healpy/projaxes.py:1050: RuntimeWarning: invalid value encountered in greater
#   result.data[result.data>1]=1.0

# %%
hp.mollview(scheduler.survey_lists[0][2].basis_functions[0](conditions))

# %%
hp.mollview(scheduler.survey_lists[0][2].basis_functions[1](conditions))

# %%
hp.mollview(scheduler.survey_lists[0][2].basis_functions[2](conditions))

# %%
hp.mollview(scheduler.survey_lists[0][2].hp2fields)

# %%
scheduler.survey_lists[0][2].nside
# Out:
# 256

# %%
scheduler.survey_lists[0][2].fields_init.size
# Out:
# 119451

# %%
order = np.argsort(reward)[::-1]
order = order[~np.isnan(reward[order])]
order
# Out:
# array([679327, 680250, 681169, ..., 658888, 659896, 660900])

# %%
reward[689074]
# Out:
# nan

# %%
scheduler.survey_lists[0][2].hp2fields[689074]
# Out:
# 104038

# %%
scheduler.survey_lists[0][2].fields[104038]
# Out:
# (5.43917231, -0.84740328)
