# %%
import numpy as np
import healpy as hp
import matplotlib.pylab as plt
# %matplotlib inline
from comCam_runs import greedy_comcam, run_sched, blob_comcam

# %%
nside = 256
survey_length = 2.  # Days
blob = blob_comcam(nexp=1, nside=nside)
greedy = greedy_comcam(nexp=1, nside=nside)
survey_lol = [blob, greedy]

# %%
observatory, scheduler, observations = run_sched(survey_lol, nside=nside, 
                                                 fileroot='comcam_blob', n_visit_limit=None,
                                                survey_length=survey_length)
# Out:
# WARNING: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)" [astropy._erfa.core]
# /Users/yoachim/gitRepos/sims_skybrightness_pre/python/lsst/sims/skybrightness_pre/SkyModelPre.py:377: UserWarning: Requested MJD between sunrise and sunset, returning closest maps
#   warnings.warn('Requested MJD between sunrise and sunset, returning closest maps')
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/modelObservatory/model_observatory.py:437: RuntimeWarning: invalid value encountered in less
#   slewtimes[np.where(slewtimes < 0)] = np.nan
# progress = 100.05%Skipped 0 observations
# Flushed 0 observations from queue for being stale
# Completed 1969 observations
# ran in 6 min = 0.1 hours
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/sim_runner.py:98: UserWarning: Failed to get info about run, may need to run scons in some pacakges.
#   warnings.warn('Failed to get info about run, may need to run scons in some pacakges.')

# %%
hp.mollview(scheduler.survey_lists[0][2].basis_functions[1].survey_features['N_obs'].feature)

# %%
hp.mollview(scheduler.survey_lists[0][1].basis_functions[1].survey_features['N_obs'].feature)

# %%
conditions = observatory.return_conditions()
# Out:
# /Users/yoachim/gitRepos/sims_skybrightness_pre/python/lsst/sims/skybrightness_pre/SkyModelPre.py:377: UserWarning: Requested MJD between sunrise and sunset, returning closest maps
#   warnings.warn('Requested MJD between sunrise and sunset, returning closest maps')
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/modelObservatory/model_observatory.py:437: RuntimeWarning: invalid value encountered in less
#   slewtimes[np.where(slewtimes < 0)] = np.nan

# %%
conditions.mjd, conditions.sun_n18_setting
# Out:
# (array([ 59855.98474832]), array([ 59856.00466525]))

# %%
observatory.mjd += 0.2
conditions = observatory.return_conditions()
# Out:
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/modelObservatory/model_observatory.py:437: RuntimeWarning: invalid value encountered in less
#   slewtimes[np.where(slewtimes < 0)] = np.nan

# %%
reward = scheduler.survey_lists[0][2].calc_reward_function(conditions)

# %%
hp.mollview(reward)
# Out:
# /Users/yoachim/lsstp3/stack/miniconda3-4.3.21-10a4fa6/DarwinX86/healpy/1.10.3.lsst1+6/lib/python/healpy-1.10.3-py3.6-macosx-10.7-x86_64.egg/healpy/pixelfunc.py:304: RuntimeWarning: invalid value encountered in less_equal
#   return np.absolute(m - badval) <= atol + rtol * np.absolute(badval)
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/numpy/ma/core.py:2344: RuntimeWarning: invalid value encountered in less_equal
#   mabs(xnew - value), atol + rtol * mabs(value))
# /Users/yoachim/lsstp3/stack/miniconda3-4.3.21-10a4fa6/DarwinX86/healpy/1.10.3.lsst1+6/lib/python/healpy-1.10.3-py3.6-macosx-10.7-x86_64.egg/healpy/projaxes.py:1049: RuntimeWarning: invalid value encountered in less
#   result.data[result.data<0]=0.0
# /Users/yoachim/lsstp3/stack/miniconda3-4.3.21-10a4fa6/DarwinX86/healpy/1.10.3.lsst1+6/lib/python/healpy-1.10.3-py3.6-macosx-10.7-x86_64.egg/healpy/projaxes.py:1050: RuntimeWarning: invalid value encountered in greater
#   result.data[result.data>1]=1.0

# %%
hp.mollview(scheduler.survey_lists[0][2].basis_functions[0](conditions))
# Out:
# /Users/yoachim/lsstp3/stack/miniconda3-4.3.21-10a4fa6/DarwinX86/healpy/1.10.3.lsst1+6/lib/python/healpy-1.10.3-py3.6-macosx-10.7-x86_64.egg/healpy/pixelfunc.py:304: RuntimeWarning: invalid value encountered in less_equal
#   return np.absolute(m - badval) <= atol + rtol * np.absolute(badval)
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/numpy/ma/core.py:2344: RuntimeWarning: invalid value encountered in less_equal
#   mabs(xnew - value), atol + rtol * mabs(value))
# /Users/yoachim/lsstp3/stack/miniconda3-4.3.21-10a4fa6/DarwinX86/healpy/1.10.3.lsst1+6/lib/python/healpy-1.10.3-py3.6-macosx-10.7-x86_64.egg/healpy/projaxes.py:1049: RuntimeWarning: invalid value encountered in less
#   result.data[result.data<0]=0.0
# /Users/yoachim/lsstp3/stack/miniconda3-4.3.21-10a4fa6/DarwinX86/healpy/1.10.3.lsst1+6/lib/python/healpy-1.10.3-py3.6-macosx-10.7-x86_64.egg/healpy/projaxes.py:1050: RuntimeWarning: invalid value encountered in greater
#   result.data[result.data>1]=1.0

# %%
hp.mollview(scheduler.survey_lists[0][2].basis_functions[1](conditions))
# Out:
# /Users/yoachim/lsstp3/stack/miniconda3-4.3.21-10a4fa6/DarwinX86/healpy/1.10.3.lsst1+6/lib/python/healpy-1.10.3-py3.6-macosx-10.7-x86_64.egg/healpy/pixelfunc.py:304: RuntimeWarning: invalid value encountered in less_equal
#   return np.absolute(m - badval) <= atol + rtol * np.absolute(badval)
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/numpy/ma/core.py:2344: RuntimeWarning: invalid value encountered in less_equal
#   mabs(xnew - value), atol + rtol * mabs(value))
# /Users/yoachim/lsstp3/stack/miniconda3-4.3.21-10a4fa6/DarwinX86/healpy/1.10.3.lsst1+6/lib/python/healpy-1.10.3-py3.6-macosx-10.7-x86_64.egg/healpy/projaxes.py:1049: RuntimeWarning: invalid value encountered in less
#   result.data[result.data<0]=0.0
# /Users/yoachim/lsstp3/stack/miniconda3-4.3.21-10a4fa6/DarwinX86/healpy/1.10.3.lsst1+6/lib/python/healpy-1.10.3-py3.6-macosx-10.7-x86_64.egg/healpy/projaxes.py:1050: RuntimeWarning: invalid value encountered in greater
#   result.data[result.data>1]=1.0

# %%
hp.mollview(scheduler.survey_lists[0][2].basis_functions[2](conditions))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/lsstp3/stack/miniconda3-4.3.21-10a4fa6/DarwinX86/healpy/1.10.3.lsst1+6/lib/python/healpy-1.10.3-py3.6-macosx-10.7-x86_64.egg/healpy/pixelfunc.py in ma_to_array(m)
#     232     try:
# --> 233         return m.filled()
#     234     except AttributeError:
#
# AttributeError: 'int' object has no attribute 'filled'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-1a40401d63f9> in <module>()
# ----> 1 hp.mollview(scheduler.survey_lists[0][2].basis_functions[2](conditions))
#
# ~/lsstp3/stack/miniconda3-4.3.21-10a4fa6/DarwinX86/healpy/1.10.3.lsst1+6/lib/python/healpy-1.10.3-py3.6-macosx-10.7-x86_64.egg/healpy/visufunc.py in mollview(map, fig, rot, coord, unit, xsize, title, nest, min, max, flip, remove_dip, remove_mono, gal_cut, format, format2, cbar, cmap, notext, norm, hold, margins, sub, return_projected_map)
#     181             map = np.zeros(12)+np.inf
#     182             cbar=False
# --> 183         map = pixelfunc.ma_to_array(map)
#     184         ax=PA.HpxMollweideAxes(f,extent,coord=coord,rot=rot,
#     185                                format=format2,flipconv=flip)
#
# ~/lsstp3/stack/miniconda3-4.3.21-10a4fa6/DarwinX86/healpy/1.10.3.lsst1+6/lib/python/healpy-1.10.3-py3.6-macosx-10.7-x86_64.egg/healpy/pixelfunc.py in ma_to_array(m)
#     234     except AttributeError:
#     235         try:
# --> 236             return tuple([mm.filled() for mm in m])
#     237         except AttributeError:
#     238             pass
#
# TypeError: 'int' object is not iterable

# %%
hp.mollview(scheduler.survey_lists[0][2].hp2fields)

# %%
scheduler.survey_lists[0][2].nside
# Out:
# 256

# %%
scheduler.survey_lists[0][2].fields_init.size
# Out:
# 119451

# %%
order = np.argsort(reward)[::-1]
order = order[~np.isnan(reward[order])]
order
# Out:
# array([645694, 646717, 645695, ..., 667038, 671876, 670917])

# %%
reward[689074]
# Out:
# nan

# %%
scheduler.survey_lists[0][2].hp2fields[689074]
# Out:
# 104038

# %%
scheduler.survey_lists[0][2].fields[104038]
# Out:
# ( 5.43917231, -0.84740328)

# %%
np.mean(observations['slewtime'])
# Out:
# 4.9569333340686974
