# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles

# %%
dbFile = 'baseline_1exp_pairsmix_10yrs.db'
# This connection checks which version it thinks the database is and should do the right thing schema-wise
conn = db.OpsimDatabase(dbFile)
outDir='temp'
resultsDb = db.ResultsDb(outDir=outDir)

# %%
bundleList = []

ss = metrics.MedianMetric()
for filtername in ['u', 'g', 'r', 'i', 'z', 'y']:
    metric = metrics.OptimalM5Metric(magDiff=True, metricName='magdiff')
    slicer = slicers.HealpixSlicer()
    sql = 'filter = "%s"' % filtername
    bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, summaryMetrics=[ss]))
    metric = metrics.OptimalM5Metric(normalize=True, metricName='frac behind')
    bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, summaryMetrics=[ss]))
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()
bg.plotAll(closefigs=False)
# Out:
# Querying database SummaryAllProps with constraint filter = "y" for columns ['fieldDec', 'sunAlt', 'fiveSigmaDepth', 'moonAlt', 'fieldRA', 'visitExposureTime', 'airmass', 'filter', 'seeingFwhmEff', 'skyBrightness']
# Found 422012 visits
# Running:  ['opsim_magdiff_y_HEAL', 'opsim_frac_behind_y_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter = "u" for columns ['fieldDec', 'sunAlt', 'fiveSigmaDepth', 'moonAlt', 'fieldRA', 'visitExposureTime', 'airmass', 'filter', 'seeingFwhmEff', 'skyBrightness']
# Found 160469 visits
# Running:  ['opsim_magdiff_u_HEAL', 'opsim_frac_behind_u_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter = "z" for columns ['fieldDec', 'sunAlt', 'fiveSigmaDepth', 'moonAlt', 'fieldRA', 'visitExposureTime', 'airmass', 'filter', 'seeingFwhmEff', 'skyBrightness']
# Found 458710 visits
# Running:  ['opsim_magdiff_z_HEAL', 'opsim_frac_behind_z_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter = "i" for columns ['fieldDec', 'sunAlt', 'fiveSigmaDepth', 'moonAlt', 'fieldRA', 'visitExposureTime', 'airmass', 'filter', 'seeingFwhmEff', 'skyBrightness']
# Found 475454 visits
# Running:  ['opsim_magdiff_i_HEAL', 'opsim_frac_behind_i_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter = "r" for columns ['fieldDec', 'sunAlt', 'fiveSigmaDepth', 'moonAlt', 'fieldRA', 'visitExposureTime', 'airmass', 'filter', 'seeingFwhmEff', 'skyBrightness']
# Found 494229 visits
# Running:  ['opsim_magdiff_r_HEAL', 'opsim_frac_behind_r_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter = "g" for columns ['fieldDec', 'sunAlt', 'fiveSigmaDepth', 'moonAlt', 'fieldRA', 'visitExposureTime', 'airmass', 'filter', 'seeingFwhmEff', 'skyBrightness']
# Found 205152 visits
# Running:  ['opsim_magdiff_g_HEAL', 'opsim_frac_behind_g_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter = "y"" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 480 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 0.0220824  dipole: lon: -47.952, lat: -34.5624, amp: 0.0123412
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 568 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 4.44678  dipole: lon: -48.9707, lat: -34.2251, amp: 2.71248
# Plotting complete.
# Plotting figures with "filter = "u"" constraint now.
# monopole: 0.0301837  dipole: lon: -82.7535, lat: -71.42, amp: 0.0186688
# monopole: 6.23557  dipole: lon: -81.2155, lat: -72.2492, amp: 3.97804
# Plotting complete.
# Plotting figures with "filter = "z"" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 434 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 0.0168027  dipole: lon: -52.4801, lat: -7.74381, amp: 0.0113503
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 469 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 3.50154  dipole: lon: -52.817, lat: -7.89321, amp: 2.42505
# Plotting complete.
# Plotting figures with "filter = "i"" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 447 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 0.0229644  dipole: lon: -58.151, lat: -29.0297, amp: 0.00950805
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 528 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 4.66298  dipole: lon: -61.2702, lat: -34.3491, amp: 2.01909
# Plotting complete.
# Plotting figures with "filter = "r"" constraint now.
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 0.0202028  dipole: lon: -43.7838, lat: -58.8556, amp: 0.0156754
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 4.08379  dipole: lon: -46.9313, lat: -59.6957, amp: 3.15886
# Plotting complete.
# Plotting figures with "filter = "g"" constraint now.
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 0.0285044  dipole: lon: -56.3113, lat: -48.7797, amp: 0.0234911
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 205 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 5.86254  dipole: lon: -58.3797, lat: -49.714, amp: 5.00507
# Plotting complete.

# %%
for bund in bundleList:
    print(bund.constraint, bund.metric.name, bund.summaryValues)
# Out:
# filter = "u" magdiff {'Median': 0.035188591090745902}
# filter = "u" frac behind {'Median': 7.2228452748684013}
# filter = "g" magdiff {'Median': 0.027992383041095081}
# filter = "g" frac behind {'Median': 5.7368465253512886}
# filter = "r" magdiff {'Median': 0.019530876650687645}
# filter = "r" frac behind {'Median': 3.9453415101591061}
# filter = "i" magdiff {'Median': 0.020325117544285121}
# filter = "i" frac behind {'Median': 4.1536071334736659}
# filter = "z" magdiff {'Median': 0.013894906309634081}
# filter = "z" frac behind {'Median': 2.8349997647935705}
# filter = "y" magdiff {'Median': 0.023488021694319627}
# filter = "y" frac behind {'Median': 4.721814546071939}

# %%
bundleList[0].metric.name
# Out:
# 'magdiff'
