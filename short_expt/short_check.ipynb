# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles

# %%
dbFile = 'shortt_5ns_1ext_pairsmix_10yrs.db'
# This connection checks which version it thinks the database is and should do the right thing schema-wise
conn = db.OpsimDatabase(dbFile)
outDir='temp'
resultsDb = db.ResultsDb(outDir=outDir)

# %%
bundleList = []
for filtername in 'ugrizy':

    metric = metrics.CountMetric(col='observationStartMJD')
    slicer = slicers.HealpixSlicer()
    sql = 'filter="%s" and note="short"' % filtername

    bundleList.append(metricBundles.MetricBundle(metric,slicer,sql))
    sql = 'filter="%s" and note!="short" and note!=""' % filtername
    bundleList.append(metricBundles.MetricBundle(metric,slicer,sql))
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()
bg.plotAll(closefigs=False)
# Out:
# Querying database SummaryAllProps with constraint filter="g" and note="short" for columns ['fieldDec', 'fieldRA', 'observationStartMJD']
# Found 118698 visits
# Running:  ['opsim_Count_observationStartMJD_g_and_noteshort_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="y" and note!="short" and note!="" for columns ['fieldDec', 'fieldRA', 'observationStartMJD']
# Found 388546 visits
# Running:  ['opsim_Count_observationStartMJD_y_and_note!short_and_note!_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="r" and note!="short" and note!="" for columns ['fieldDec', 'fieldRA', 'observationStartMJD']
# Found 459078 visits
# Running:  ['opsim_Count_observationStartMJD_r_and_note!short_and_note!_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="z" and note!="short" and note!="" for columns ['fieldDec', 'fieldRA', 'observationStartMJD']
# Found 411373 visits
# Running:  ['opsim_Count_observationStartMJD_z_and_note!short_and_note!_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="u" and note!="short" and note!="" for columns ['fieldDec', 'fieldRA', 'observationStartMJD']
# Found 104369 visits
# Running:  ['opsim_Count_observationStartMJD_u_and_note!short_and_note!_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="i" and note!="short" and note!="" for columns ['fieldDec', 'fieldRA', 'observationStartMJD']
# Found 382210 visits
# Running:  ['opsim_Count_observationStartMJD_i_and_note!short_and_note!_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="z" and note="short" for columns ['fieldDec', 'fieldRA', 'observationStartMJD']
# Found 101866 visits
# Running:  ['opsim_Count_observationStartMJD_z_and_noteshort_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="u" and note="short" for columns ['fieldDec', 'fieldRA', 'observationStartMJD']
# Found 92074 visits
# Running:  ['opsim_Count_observationStartMJD_u_and_noteshort_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="i" and note="short" for columns ['fieldDec', 'fieldRA', 'observationStartMJD']
# Found 30303 visits
# Running:  ['opsim_Count_observationStartMJD_i_and_noteshort_HEAL']
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/metricBundles/metricBundleGroup.py:495: RuntimeWarning: invalid value encountered in equal
#   b.metricValues.mask = np.where(b.metricValues.data == b.metric.badval,
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="g" and note!="short" and note!="" for columns ['fieldDec', 'fieldRA', 'observationStartMJD']
# Found 137805 visits
# Running:  ['opsim_Count_observationStartMJD_g_and_note!short_and_note!_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="r" and note="short" for columns ['fieldDec', 'fieldRA', 'observationStartMJD']
# Found 101898 visits
# Running:  ['opsim_Count_observationStartMJD_r_and_noteshort_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="y" and note="short" for columns ['fieldDec', 'fieldRA', 'observationStartMJD']
# Found 87043 visits
# Running:  ['opsim_Count_observationStartMJD_y_and_noteshort_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="g" and note="short"" constraint now.
# monopole: 38.9662  dipole: lon: -5.82345, lat: -87.8448, amp: 9.06984
# Plotting complete.
# Plotting figures with "filter="y" and note!="short" and note!=""" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 6399 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 176.034  dipole: lon: 79.2901, lat: 47.2823, amp: 53.6257
# Plotting complete.
# Plotting figures with "filter="r" and note!="short" and note!=""" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 1225 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 147.931  dipole: lon: 59.0332, lat: -70.6353, amp: 41.9579
# Plotting complete.
# Plotting figures with "filter="z" and note!="short" and note!=""" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 1700 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 130.972  dipole: lon: 62.4481, lat: -69.4692, amp: 42.7216
# Plotting complete.
# Plotting figures with "filter="u" and note!="short" and note!=""" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 9419 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 44.8973  dipole: lon: 68.7241, lat: 27.2122, amp: 10.344
# Plotting complete.
# Plotting figures with "filter="i" and note!="short" and note!=""" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 1422 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 121.626  dipole: lon: 42.6536, lat: -68.0235, amp: 40.7475
# Plotting complete.
# Plotting figures with "filter="z" and note="short"" constraint now.
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 36.8468  dipole: lon: -156.833, lat: 21.2747, amp: 5.81546
# Plotting complete.
# Plotting figures with "filter="u" and note="short"" constraint now.
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 38.2928  dipole: lon: 108.633, lat: 32.221, amp: 2.35783
# Plotting complete.
# Plotting figures with "filter="i" and note="short"" constraint now.
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 12.0714  dipole: lon: -173.579, lat: 86.0163, amp: 4.07317
# Plotting complete.
# Plotting figures with "filter="g" and note!="short" and note!=""" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 2450 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 44.1142  dipole: lon: 75.5906, lat: -66.1563, amp: 13.8467
# Plotting complete.
# Plotting figures with "filter="r" and note="short"" constraint now.
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 36.9313  dipole: lon: -38.2897, lat: 56.5633, amp: 3.28366
# Plotting complete.
# Plotting figures with "filter="y" and note="short"" constraint now.
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 30.8927  dipole: lon: -37.0978, lat: -76.2587, amp: 11.5866
# Plotting complete.
