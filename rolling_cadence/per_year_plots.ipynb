# %%
import numpy as np
import healpy as hp
import matplotlib.pylab as plt
# %matplotlib inline
import healpy as hp

import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles

# %%
dbFiles = {'mod2': 'roll_mod2_sdf0.10mixed_10yrs.db', 'mod6': 'roll_mod6_sdf0.10mixed_10yrs.db'}
for dbFile in dbFiles:
    conn = db.OpsimDatabase(dbFiles[dbFile])
    outDir='temp'
    resultsDb = db.ResultsDb(outDir=outDir)


    bundleList = []
    years = [0,1,2,3, 4, 5, 6]
    plotDict = {'percentileClip': 95.}
    for y1,y2 in zip(years[:-1], years[1:]):

        metric = metrics.CountMetric(col='observationStartMJD', metricName='Count')
        slicer = slicers.HealpixSlicer()
        sql = 'night > %i and night < %i' % (365.25*y1, 365.25*y2)
        bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict, runName=dbFile))

    bd = metricBundles.makeBundlesDictFromList(bundleList)
    bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
    bg.runAll()
    bg.plotAll(closefigs=False)
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint night > 1826 and night < 2191 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 268370 visits
# Running:  ['mod2_Count_night_gt_1826_and_night_lt_2191_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 730 and night < 1095 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 245155 visits
# Running:  ['mod2_Count_night_gt_730_and_night_lt_1095_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 365 and night < 730 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 240072 visits
# Running:  ['mod2_Count_night_gt_365_and_night_lt_730_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 1095 and night < 1461 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 267963 visits
# Running:  ['mod2_Count_night_gt_1095_and_night_lt_1461_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 0 and night < 365 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 274659 visits
# Running:  ['mod2_Count_night_gt_0_and_night_lt_365_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 1461 and night < 1826 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 268708 visits
# Running:  ['mod2_Count_night_gt_1461_and_night_lt_1826_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 1826 and night < 2191" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 716 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 93.6784  dipole: lon: -81.6173, lat: -29.4874, amp: 11.3525
# Plotting complete.
# Plotting figures with "night > 730 and night < 1095" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 1191 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 72.6096  dipole: lon: 121.303, lat: -66.6987, amp: 43.4789
# Plotting complete.
# Plotting figures with "night > 365 and night < 730" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 1359 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 83.468  dipole: lon: 59.5215, lat: -16.0246, amp: 8.64788
# Plotting complete.
# Plotting figures with "night > 1095 and night < 1461" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 695 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 95.2719  dipole: lon: -97.4769, lat: -1.1216, amp: 8.48174
# Plotting complete.
# Plotting figures with "night > 0 and night < 365" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 1065 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 88.1427  dipole: lon: -47.0861, lat: -55.2506, amp: 37.2497
# Plotting complete.
# Plotting figures with "night > 1461 and night < 1826" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 697 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 76.4095  dipole: lon: 83.9468, lat: -62.1699, amp: 57.6874
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint night > 1826 and night < 2191 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 268279 visits
# Running:  ['mod6_Count_night_gt_1826_and_night_lt_2191_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 730 and night < 1095 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 247411 visits
# Running:  ['mod6_Count_night_gt_730_and_night_lt_1095_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 365 and night < 730 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 240910 visits
# Running:  ['mod6_Count_night_gt_365_and_night_lt_730_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 1095 and night < 1461 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 268251 visits
# Running:  ['mod6_Count_night_gt_1095_and_night_lt_1461_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 0 and night < 365 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 274659 visits
# Running:  ['mod6_Count_night_gt_0_and_night_lt_365_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 1461 and night < 1826 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 269416 visits
# Running:  ['mod6_Count_night_gt_1461_and_night_lt_1826_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 1826 and night < 2191" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 2411 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 58.8857  dipole: lon: 114.188, lat: -72.5839, amp: 108.641
# Plotting complete.
# Plotting figures with "night > 730 and night < 1095" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 2533 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 116.089  dipole: lon: -179.723, lat: 83.1028, amp: 81.4546
# Plotting complete.
# Plotting figures with "night > 365 and night < 730" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 1545 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 95.0008  dipole: lon: 58.6732, lat: 78.3098, amp: 32.4794
# Plotting complete.
# Plotting figures with "night > 1095 and night < 1461" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 2384 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 104.198  dipole: lon: 143.437, lat: 56.0329, amp: 37.3118
# Plotting complete.
# Plotting figures with "night > 0 and night < 365" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 1065 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 88.1427  dipole: lon: -47.0861, lat: -55.2506, amp: 37.2497
# Plotting complete.
# Plotting figures with "night > 1461 and night < 1826" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 2836 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 81.764  dipole: lon: 118.403, lat: -55.9987, amp: 45.635
# Plotting complete.

# %%
for dbFile in dbFiles:
    conn = db.OpsimDatabase(dbFiles[dbFile])
    outDir='temp'
    resultsDb = db.ResultsDb(outDir=outDir)


    bundleList = []
    years = [0,1,2,3, 4, 5, 6]
    plotDict = {'percentileClip': 95.}
    for y1,y2 in zip(years[:-1], years[1:]):

        metric = metrics.CountMetric(col='observationStartMJD', metricName='Count')
        slicer = slicers.HealpixSlicer()
        sql = 'night > %i and night < %i' % (365.25*y1+365.25/2, 365.25*y2+365.25/2)
        bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict, runName=dbFile))

    bd = metricBundles.makeBundlesDictFromList(bundleList)
    bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
    bg.runAll()
    bg.plotAll(closefigs=False)
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint night > 182 and night < 547 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 258814 visits
# Running:  ['mod2_Count_night_gt_182_and_night_lt_547_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 913 and night < 1278 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 280182 visits
# Running:  ['mod2_Count_night_gt_913_and_night_lt_1278_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 1643 and night < 2008 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 272665 visits
# Running:  ['mod2_Count_night_gt_1643_and_night_lt_2008_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 547 and night < 913 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 223560 visits
# Running:  ['mod2_Count_night_gt_547_and_night_lt_913_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 2008 and night < 2374 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 263681 visits
# Running:  ['mod2_Count_night_gt_2008_and_night_lt_2374_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 1278 and night < 1643 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 263949 visits
# Running:  ['mod2_Count_night_gt_1278_and_night_lt_1643_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 182 and night < 547" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 1396 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 82.3869  dipole: lon: -1.70274, lat: -61.4462, amp: 31.34
# Plotting complete.
# Plotting figures with "night > 913 and night < 1278" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 793 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 66.0825  dipole: lon: 143.914, lat: -78.7271, amp: 100.431
# Plotting complete.
# Plotting figures with "night > 1643 and night < 2008" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 628 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 57.1885  dipole: lon: 81.8158, lat: -81.6254, amp: 117.288
# Plotting complete.
# Plotting figures with "night > 547 and night < 913" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 822 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 89.5703  dipole: lon: -45.3506, lat: 83.297, amp: 31.9938
# Plotting complete.
# Plotting figures with "night > 2008 and night < 2374" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 648 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 112.815  dipole: lon: 7.20997, lat: 81.323, amp: 61.2658
# Plotting complete.
# Plotting figures with "night > 1278 and night < 1643" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 539 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 113.035  dipole: lon: 14.7488, lat: 84.2173, amp: 61.4481
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint night > 182 and night < 547 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 258783 visits
# Running:  ['mod6_Count_night_gt_182_and_night_lt_547_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 913 and night < 1278 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 282238 visits
# Running:  ['mod6_Count_night_gt_913_and_night_lt_1278_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 1643 and night < 2008 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 273902 visits
# Running:  ['mod6_Count_night_gt_1643_and_night_lt_2008_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 547 and night < 913 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 225425 visits
# Running:  ['mod6_Count_night_gt_547_and_night_lt_913_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 2008 and night < 2374 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 263424 visits
# Running:  ['mod6_Count_night_gt_2008_and_night_lt_2374_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint night > 1278 and night < 1643 for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 263522 visits
# Running:  ['mod6_Count_night_gt_1278_and_night_lt_1643_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 182 and night < 547" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 1397 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 82.6156  dipole: lon: -1.74446, lat: -60.6616, amp: 30.7562
# Plotting complete.
# Plotting figures with "night > 913 and night < 1278" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 2761 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 122.014  dipole: lon: 165.736, lat: 74.6111, amp: 70.717
# Plotting complete.
# Plotting figures with "night > 1643 and night < 2008" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 3219 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 72.5931  dipole: lon: 114.008, lat: -73.8391, amp: 73.5417
# Plotting complete.
# Plotting figures with "night > 547 and night < 913" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 3023 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 112.767  dipole: lon: -117.315, lat: 87.4136, amp: 95.534
# Plotting complete.
# Plotting figures with "night > 2008 and night < 2374" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 3501 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 48.0065  dipole: lon: 104.07, lat: -77.0867, amp: 136.506
# Plotting complete.
# Plotting figures with "night > 1278 and night < 1643" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 2677 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 90.9665  dipole: lon: 121.854, lat: -14.6741, amp: 20.0803
# Plotting complete.
